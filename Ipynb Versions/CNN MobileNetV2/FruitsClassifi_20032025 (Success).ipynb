# %% [markdown]
# **Các thay đổi chính:**
# - Đổi qua sử dụng mô hình MobileNetV2 thay vì VGG16.
# - Tiền xử lý ảnh tải từ Google (nếu có sử dụng) giống dữ liệu huấn luyện.
# - Giảm classnames trong tệp huấn luyện từ 5 -> 3.
# - Rebuild lại tệp dữ liệu:
#   + Phiên bản 19.03.2025 phạm 1 lỗi nghiêm trong là để tệp Test và tệp Training y hệt nhau (vi phạm nguyên tắc cơ bản trong máy học: tập kiểm tra phải độc lập với tập huấn luyện)
#   + Phiên bản 19.03.2025 train theo mô hình VGG16:
#     - Dễ gây ra Overfitting nặng nếu tập dữ liệu không đủ lớn.
#     - Quá nặng để chạy và xử lý mượt mà trên Raspberry.
#
# ---------------------------------------
# **Kết quả:**
# - Mô hình đã nhận diện chính xác ảnh từ bên ngoài với độ tin cậy > 80%.
# - Có dấu hiệu Over fitting khá cao, cần điều chỉnh thêm ở phiên bản tiếp theo.

# %% [markdown]
# Liên kết đến Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Hàm tạo mô hình MobilenetV2

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os
import matplotlib.pyplot as plt
import json

def train_mobilenetv2_model(train_dir, val_dir, num_classes=5, epochs=50, model_save_path='mobilenetv2_fruits.h5', tflite_save_path='mobilenetv2_fruits.tflite'):
    """
    Huấn luyện mô hình MobileNetV2 cho bài toán phân loại ảnh.

    Args:
        train_dir (str): Đường dẫn đến thư mục chứa dữ liệu huấn luyện.
        val_dir (str): Đường dẫn đến thư mục chứa dữ liệu validation.
        num_classes (int): Số lượng lớp (mặc định là 3: 'Apple', 'Banana', 'Orange').
        epochs (int): Số epoch tối đa để huấn luyện.
        model_save_path (str): Đường dẫn để lưu mô hình .h5.
        tflite_save_path (str): Đường dẫn để lưu mô hình TFLite.

    Returns:
        history: Lịch sử huấn luyện (accuracy, loss qua các epoch).
    """
    # 1. Tạo ImageDataGenerator để tải và tiền xử lý dữ liệu ảnh
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.3,
        height_shift_range=0.3,
        shear_range=0.3,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5, 1.5],
        fill_mode='nearest'
    )

    val_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical'
    )

    val_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical'
    )

    # Kiểm tra số lượng ảnh trong mỗi lớp
    print("Số lượng ảnh trong tập huấn luyện:")
    for cls in train_generator.class_indices.keys():
        cls_path = os.path.join(train_dir, cls)
        num_images = len(os.listdir(cls_path))
        print(f"{cls}: {num_images} ảnh")
        if num_images < 10:
            print(f"Cảnh báo: Lớp {cls} có quá ít ảnh ({num_images}), có thể ảnh hưởng đến hiệu suất!")

    print("\nSố lượng ảnh trong tập validation:")
    for cls in val_generator.class_indices.keys():
        cls_path = os.path.join(val_dir, cls)
        num_images = len(os.listdir(cls_path))
        print(f"{cls}: {num_images} ảnh")
        if num_images < 3:
            print(f"Cảnh báo: Lớp {cls} có quá ít ảnh ({num_images}), không đủ để đánh giá hiệu suất!")

    # 2. Tạo mô hình MobileNetV2
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Đóng băng các tầng để giảm overfitting

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)  # Thêm Dropout để giảm overfitting
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # Biên dịch mô hình
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # 3. Thêm callback để tối ưu hóa huấn luyện
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )

    # 4. Huấn luyện mô hình
    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=val_generator,
        callbacks=[early_stopping, reduce_lr]
    )

    # 5. Lưu mô hình .h5
    model.save(model_save_path)
    print(f"Mô hình đã được lưu tại: {model_save_path}")

    # 6. Chuyển mô hình sang TFLite
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Tối ưu hóa để tăng tốc độ
    tflite_model = converter.convert()

    with open(tflite_save_path, 'wb') as f:
        f.write(tflite_model)
    print(f"Mô hình TFLite đã được lưu tại: {tflite_save_path}")

    # 7. Lưu lịch sử huấn luyện
    history_dict = {
        'loss': history.history['loss'],
        'accuracy': history.history['accuracy'],
        'val_loss': history.history['val_loss'],
        'val_accuracy': history.history['val_accuracy']
    }
    with open('training_history.json', 'w') as f:
        json.dump(history_dict, f)
    print("Lịch sử huấn luyện đã được lưu tại: training_history.json")

    # 8. Vẽ biểu đồ accuracy và loss
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_plots.png')
    print("Biểu đồ huấn luyện đã được lưu tại: training_plots.png")

    return history

# %% [markdown]
# Sử dụng hàm

# %%
train_dir = '/content/drive/MyDrive/Colab Notebooks/CustomDatasetFruits/Version 20.03.2025/Training'
valid_dir = '/content/drive/MyDrive/Colab Notebooks/CustomDatasetFruits/Version 20.03.2025/Validation'
test_dir = '/content/drive/MyDrive/Colab Notebooks/CustomDatasetFruits/Version 20.03.2025/Testing'

history = train_mobilenetv2_model(train_dir, valid_dir, num_classes=3, model_save_path='FruitsClassifi_MobileNetV2.h5', tflite_save_path='FruitsClassifi_MobileNetV2.tflite')
# Out:
# Found 125 images belonging to 3 classes.
# Found 16 images belonging to 3 classes.
# Số lượng ảnh trong tập huấn luyện:
# Apple: 45 ảnh
# Banana: 40 ảnh
# Orange: 40 ảnh
#
# Số lượng ảnh trong tập validation:
# Apple: 6 ảnh
# Banana: 5 ảnh
# Orange: 5 ảnh
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 42s 9s/step - accuracy: 0.5668 - loss: 1.0222 - val_accuracy: 1.0000 - val_loss: 0.2203 - learning_rate: 0.0010
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.8600 - loss: 0.3830 - val_accuracy: 1.0000 - val_loss: 0.1338 - learning_rate: 0.0010
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.9358 - loss: 0.1950 - val_accuracy: 1.0000 - val_loss: 0.0725 - learning_rate: 0.0010
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9799 - loss: 0.1251 - val_accuracy: 0.9375 - val_loss: 0.1189 - learning_rate: 0.0010
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9584 - loss: 0.1071 - val_accuracy: 0.8750 - val_loss: 0.1850 - learning_rate: 0.0010
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9518 - loss: 0.0885 - val_accuracy: 1.0000 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 1.0000 - loss: 0.0352 - val_accuracy: 0.9375 - val_loss: 0.0609 - learning_rate: 0.0010
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.9388 - loss: 0.1175 - val_accuracy: 1.0000 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.9883 - loss: 0.0371 - val_accuracy: 1.0000 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9914 - loss: 0.0225 - val_accuracy: 0.8750 - val_loss: 0.1138 - learning_rate: 0.0010
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9727 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0501 - learning_rate: 0.0010
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 1.0000 - loss: 0.0377 - val_accuracy: 1.0000 - val_loss: 0.0268 - learning_rate: 0.0010
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.9946 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0112 - learning_rate: 0.0010
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.9741 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.9946 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.9968 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9882 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9968 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0235 - learning_rate: 0.0010
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9915 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0106 - learning_rate: 2.0000e-04
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.9882 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0078 - learning_rate: 2.0000e-04
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9947 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 0.0064 - learning_rate: 2.0000e-04
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0056 - learning_rate: 2.0000e-04
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0054 - learning_rate: 2.0000e-04
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.9914 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0053 - learning_rate: 2.0000e-04
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0053 - learning_rate: 2.0000e-04
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.9851 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0056 - learning_rate: 2.0000e-04
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.9968 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0062 - learning_rate: 2.0000e-04
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0073 - learning_rate: 2.0000e-04
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0074 - learning_rate: 4.0000e-05
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.9915 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0073 - learning_rate: 4.0000e-05
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.9946 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0070 - learning_rate: 4.0000e-05
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.9853 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0069 - learning_rate: 4.0000e-05
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.9851 - loss: 0.0409 - val_accuracy: 1.0000 - val_loss: 0.0066 - learning_rate: 4.0000e-05
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0066 - learning_rate: 8.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mô hình đã được lưu tại: FruitsClassifi_MobileNetV2.h5
# Saved artifact at '/tmp/tmpe1wecd3g'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_158')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   133312593762000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593762384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593762960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593764304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593764688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593765072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593764880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593766224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593766608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593766992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593766800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593763152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593768144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593768528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593768912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593768720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593763920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593770064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593770448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593770832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593770640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593771984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593772368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593772176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312593769680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436781520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436782864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436783248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436781712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436784400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436784784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436785168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436784976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436782288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436786320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436786704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436787088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436786896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436788240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436788624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436789008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436788816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436784016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436790160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436790544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436790928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436790736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436785936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436792080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436792848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436792656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436787856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436794384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436789776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436796304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436796496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436795536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437127504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437129808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437132112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437127120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437133648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437135568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437135952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437137872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437132880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437139792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437139600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437134800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437140944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437141328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437141136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437138640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437519760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437520144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437520336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437521680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437522448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437522256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437523600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437523984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437524368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437524176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437526288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437521296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437527440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437523216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437529744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437530128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437529936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437525136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437531280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437531664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437532048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437527056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437533200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437533584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437528976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435864592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312437532816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435865936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435866320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435866704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435866512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435864016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435867856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435864400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435870160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435870544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435865552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435872080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435874000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435875920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435876112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435877456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435878224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435879376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435864784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435879760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312435877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436241040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436251984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436255824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436634640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436633680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436633872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436635984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436636368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436636752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436634064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436637904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436638288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436638672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436638480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436634448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436639824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436640208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436640592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436640400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436635600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436637520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436642320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436639440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133312436643472: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Mô hình TFLite đã được lưu tại: FruitsClassifi_MobileNetV2.tflite
# Lịch sử huấn luyện đã được lưu tại: training_history.json
# Biểu đồ huấn luyện đã được lưu tại: training_plots.png

# %% [markdown]
# Đánh giá trên tập Test

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Found 16 images belonging to 3 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6fef943c8b7c> in <cell line: 0>()
#       8 )
#       9
# ---> 10 test_loss, test_accuracy = model.evaluate(test_generator)
#      11 print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
#
# NameError: name 'model' is not defined

# %% [markdown]
# Thử nghiệm mô hình

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# model_path = '/content/drive/MyDrive/Colab Notebooks/Results/mobilenetv2_fruits_20032025.h5'     # Thay bằng đường dẫn đến file .h5 của bạn
# model_path = 'FruitsClassifi_MobileNetV2.h5'
# model = tf.keras.models.load_model(model_path)
# print("Mô hình đã được tải thành công!")

image_path = '/content/drive/MyDrive/Colab Notebooks/Test all/Banana New/Banana 4.jpg'              # Thay bằng đường dẫn đến ảnh của bạn
img = Image.open(image_path).resize((224, 224)).convert('RGB')                          # Resize ảnh về kích thước 224x224
img_array = np.array(img, dtype=np.float32) / 255.0                                     # Chuẩn hóa giá trị pixel về [0, 1]
img_array = np.expand_dims(img_array, axis=0)                                           # Thêm chiều batch (1, 224, 224, 3)
print("Ảnh đã được tải thành công!")

class_labels = ['Apple', 'Banana', 'Orange']
predictions = model.predict(img_array)
predicted_class = class_labels[np.argmax(predictions)]
confidence = np.max(predictions) * 100

print(f"Dự đoán: {predicted_class} với độ tin cậy {confidence:.2f}%")

plt.imshow(img)
plt.title(f"Dự đoán: {predicted_class} ({confidence:.2f}%)")
plt.axis('off')
plt.show()
# Out:
# Ảnh đã được tải thành công!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Dự đoán: Banana với độ tin cậy 99.97%
